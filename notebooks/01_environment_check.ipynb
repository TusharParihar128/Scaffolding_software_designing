# %%
import sys

# %%
print(sys.executable)
# Out:
# /home/tushar-parihar/Scaffolding_software_designing/venv/bin/python

# %%
import numpy

# %%
import pandas as pd

# %%
print(numpy.__version__)
# Out:
# 2.4.0

# %%
print(pd.__version__)
# Out:
# 2.3.3
